# %% [markdown]
# # Integrando conjuntos de dados diferentes com Pandas/Python

# %% [markdown]
# _Tipo de joins na função merge_

# %% [markdown]
# ![join_types.webp](attachment:join_types.webp)

# %% [markdown]
# ## 1. Comparar as cotações entre yfinance e trading view

# %% [markdown]
# __Importando as Bibliotecas__

# %%
import pandas as pd

import yfinance as yf
import investpy as inv

# %%
petro4_yf = yf.download('PETR4.SA', period='max')[['Adj Close']]
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
# Adj Close

petro4_yf
# Out:
#             Adj Close
# Date
# 2000-01-03   2.139588
# 2000-01-04   2.021228
# 2000-01-05   2.000833
# 2000-01-06   1.993914
# 2000-01-07   2.003018
# ...               ...
# 2022-09-22  31.940001
# 2022-09-23  29.940001
# 2022-09-26  29.290001
# 2022-09-27  29.670000
# 2022-09-28  29.270000
#
# [5715 rows x 1 columns]

# %%
petro4_inv = inv.get_stock_historical_data('PETR4', country='brazil', from_date='01/01/2000', to_date='29/09/2022')
# Out:
# ---------------------------------------------------------------------------
# ConnectionError                           Traceback (most recent call last)
# Input In [17], in <cell line: 1>()
# ----> 1 petro4_inv = inv.get_stock_historical_data('PETR4', country='brazil', from_date='01/01/2000', to_date='29/09/2022')
#
# File ~\anaconda3\lib\site-packages\investpy\stocks.py:664, in get_stock_historical_data(stock, country, from_date, to_date, as_json, order, interval)
#     661 req = requests.post(url, headers=head, data=params)
#     663 if req.status_code != 200:
# --> 664     raise ConnectionError(
#     665         "ERR#0015: error " + str(req.status_code) + ", try again later."
#     666     )
#     668 if not req.text:
#     669     continue
#
# ConnectionError: ERR#0015: error 403, try again later.
